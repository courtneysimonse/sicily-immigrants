# %% [markdown]
# ## Formatting Passenger Data

# %%
import pandas as pd
import numpy as np

# %%
# open data file
csv = open('../data/sicily_passengers.csv')
df = pd.read_csv(csv)

# %%
df.head()
# Out:
#    index    LastName  FirstName                   Age        Occupation  \
# 0      0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1      1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2      2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3      3      CARUSO  FRANCESCO                     3  CHILD, YOUNGSTER
# 4      4      CARUSO       ROSA                    38              WIFE
#
#        Literacy origin_country origin_city destination_city  \
# 0  READ & WRITE          ITALY     SCIACCA         NEW YORK
# 1  READ & WRITE          ITALY     SCIACCA         NEW YORK
# 2            NO          ITALY     SCIACCA         NEW YORK
# 3            NO          ITALY     SCIACCA         NEW YORK
# 4  READ & WRITE          ITALY     SCIACCA         NEW YORK
#
#                             TransitTravelCompartment  ...  ShipName    Port  \
# 0  Return trip to USA - non US Citizen [Transit];...  ...       EMS  NAPLES
# ...

# %%
df.apply(lambda x: x.str.capitalize()  columns=['LastName', 'FirstName', 'Occupation', 'Literacy', 'origin_city', 'destination_city'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-cf854064e1b5> in <module>
# ----> 1 df.apply(lambda x: x.str.capitalize(), columns=['LastName', 'FirstName', 'Occupation', 'Literacy', 'origin_city', 'destination_city'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
# ...
