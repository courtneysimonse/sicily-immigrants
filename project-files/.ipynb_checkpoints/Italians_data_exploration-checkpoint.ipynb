# %%
import pandas as pd
import numpy as np

# %%
# open the three passenger data files
csv1 = open('./italians_parta.csv', 'r', newline='')
csv2 = open('./italians_partb.csv', 'r', newline='')
csv3 = open('./italians_partc.csv', 'r', newline='')

# %%
# create pandas dataframes from the csv files
df1 = pd.read_csv(csv1)
df2 = pd.read_csv(csv2)
df3 = pd.read_csv(csv3)

# %%
# combine the three passenger files
df = df1.append([df2,df3], sort=False)
df.head()
# Out:
#      LastName  FirstName Age    Occupation      Literacy CountyofOrigin  \
# 0      ZERONI      CARLO  39  MANUFACTURER  READ & WRITE          ITALY
# 1       ARATA       ANNA  16        FARMER       UNKNOWN          ITALY
# 2   BRILLANTI  SALVATORE  34     FISHERMAN            NO          ITALY
# 3  BUONGIORNO    ANTONIO  49    BLACKSMITH  READ & WRITE          ITALY
# 4  BUONGIORNO   GIUSEPPE  60    BLACKSMITH  READ & WRITE          ITALY
#
#   CityTownofLastResidence DestinationCityTown  \
# 0               MIDDLESEX          CALIFORNIA
# 1           SAN-FRANCISCO       SAN-FRANCISCO
# 2                   ITALY            NEW YORK
# 3                 SCIACCA            NEW YORK
# 4                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID
# 0  Return trip to USA - non US Citizen [Transit];...     82279.0
# 1  Return trip to USA - non US Citizen [Transit];...     80120.0
# 2  Return trip to USA - non US Citizen [Transit];...     82224.0
# 3  Return trip to USA - non US Citizen [Transit];...     82236.0
# 4  Return trip to USA - non US Citizen [Transit];...     82236.0

# %%
# get an idea of the towns listed as previous last residence
df['CityTownofLastResidence'].value_counts()
# Out:
# U                 383977
# NAPOLI             10717
# PALERMO             6644
# NEW YORK            6293
# TERMINI             4276
#                    ...
# CARELLE TORINO         1
# CASTELVERNA            1
# CASTIO---              1
# SALORNO                1
# GIUPERRA               1
# Name: CityTownofLastResidence, Length: 27334, dtype: int64

# %%
# get an idea of the destination towns listed
df['DestinationCityTown'].value_counts()
# Out:
# NEW YORK            419099
# USA                 118909
# BROOKLYN             15187
# PHILADELPHIA         14521
# BOSTON               12447
#                      ...
# ALBIANO                  1
# COURZOLO                 1
# MILFORD UT               1
# WERMINGTON               1
# SAM-FRANCISCO-CA         1
# Name: DestinationCityTown, Length: 12713, dtype: int64

# %%
# look at Manifest IDs
df['ManifestID'].value_counts()
# Out:
# 81903.0     1709
# 81818.0     1456
# 81866.0     1452
# 82765.0     1445
# 81189.0     1436
#             ...
# 901719.0       1
# 901473.0       1
# 901416.0       1
# 9803.0         1
# 36432.0        1
# Name: ManifestID, Length: 4483, dtype: int64

# %%
# number of unique Manifest IDs
df['ManifestID'].nunique()
# Out:
# 4483

# %%
# list of Communes with assoicated Province in Sicily
communes = pd.read_csv('./communes_sicily.csv')

# %%
communes.head()
# Out:
#             Commune Province Population
# 0             Acate   Ragusa      9,574
# 1    Aci Bonaccorsi  Catania      3,200
# 2      Aci Castello  Catania     18,122
# 3        Aci Catena  Catania     28,749
# 4  Aci Sant'Antonio  Catania     17,270

# %%
# make commune name uppercase to match passenger data
communes['Commune'] = communes['Commune'].str.upper();

# %%
df['CityTownofLastResidence'].isin(communes['Commune']).value_counts() #39,725 immigrants from Sicily
# Out:
# False    729149
# True      39725
# Name: CityTownofLastResidence, dtype: int64

# %%
# create new df of only Sicilian passengers by matching reported last residence to Sicily Communes list
sicilydf = df[df['CityTownofLastResidence'].isin(communes['Commune']) == True]
sicilydf
# Out:
#          LastName  FirstName                   Age        Occupation  \
# 3      BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 4      BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 5          CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 6          CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 7          CARUSO       ROSA                    38              WIFE
# ...           ...        ...                   ...               ...
# 98350        ZUNO   GIOVANNI                    15           LABORER
# 98351        ZUNO   GIUSEPPE                    22           LABORER
# 98395     ZUPINGA   VINCENZO                    27         SHOEMAKER
# 98443    ZUPPARDO   GIUSEPPE                    48           LABORER
# 98609   ----ZZATI    CARMELA                    08  CHILD, YOUNGSTER
#
#            Literacy CountyofOrigin CityTownofLastResidence  \
# 3      READ & WRITE          ITALY                 SCIACCA
# 4      READ & WRITE          ITALY                 SCIACCA
# 5                NO          ITALY                 SCIACCA
# 6                NO          ITALY                 SCIACCA
# 7      READ & WRITE          ITALY                 SCIACCA
# ...             ...            ...                     ...
# 98350            NO          ITALY                  LIPARI
# 98351            NO          ITALY                  LIPARI
# 98395  READ & WRITE          ITALY               MISTRETTA
# 98443            NO          ITALY              CAMPOREALE
# 98609       UNKNOWN          ITALY                 SCIACCA
#
#       DestinationCityTown                           TransitTravelCompartment  \
# 3                NEW YORK  Return trip to USA - non US Citizen [Transit];...
# 4                NEW YORK  Return trip to USA - non US Citizen [Transit];...
# 5                NEW YORK  Return trip to USA - non US Citizen [Transit];...
# 6                NEW YORK  Return trip to USA - non US Citizen [Transit];...
# 7                NEW YORK  Return trip to USA - non US Citizen [Transit];...
# ...                   ...                                                ...
# 98350            BROOKLYN        Staying in the USA [Transit]; Steer[Travel]
# 98351         BROOKLYN NY        Staying in the USA [Transit]; Steer[Travel]
# 98395            NEW YORK        Staying in the USA [Transit]; Steer[Travel]
# 98443         NEW-ORLEANS        Staying in the USA [Transit]; Steer[Travel]
# 98609            NEW YORK        Staying in the USA [Transit]; Steer[Travel]
#
#        ManifestID
# 3         82236.0
# 4         82236.0
# 5         82236.0
# 6         82236.0
# 7         82236.0
# ...           ...
# 98350     83188.0
# 98351     83439.0
# 98395     83012.0
# 98443     83122.0
# 98609     81738.0
#
# [39725 rows x 10 columns]

# %%
# match Commune with previous residence to add Province column
sicilydf = pd.merge(sicilydf,communes,how='left',left_on='CityTownofLastResidence',right_on='Commune')

# %%
# drop population and duplicate Commune columns
sicilydf = sicilydf.drop(['Population','Commune'],axis='columns')

# %%
df['CityTownofLastResidence'].isna().value_counts()
# Out:
# False    768132
# True        742
# Name: CityTownofLastResidence, dtype: int64

# %%
sicilydf.head()
# Out:
#      LastName  FirstName                   Age        Occupation  \
# 0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3      CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 4      CARUSO       ROSA                    38              WIFE
#
#        Literacy CountyofOrigin CityTownofLastResidence DestinationCityTown  \
# 0  READ & WRITE          ITALY                 SCIACCA            NEW YORK
# 1  READ & WRITE          ITALY                 SCIACCA            NEW YORK
# 2            NO          ITALY                 SCIACCA            NEW YORK
# 3            NO          ITALY                 SCIACCA            NEW YORK
# 4  READ & WRITE          ITALY                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID   Province
# 0  Return trip to USA - non US Citizen [Transit];...     82236.0  Agrigento
# 1  Return trip to USA - non US Citizen [Transit];...     82236.0  Agrigento
# 2  Return trip to USA - non US Citizen [Transit];...     82236.0  Agrigento
# 3  Return trip to USA - non US Citizen [Transit];...     82236.0  Agrigento
# 4  Return trip to USA - non US Citizen [Transit];...     82236.0  Agrigento

# %%
sicilydf['Province'].value_counts()
# Out:
# Palermo          21977
# Messina           6560
# Agrigento         6076
# Enna              1713
# Trapani           1316
# Caltanissetta     1099
# Catania            560
# Siracusa           354
# Ragusa              70
# Name: Province, dtype: int64

# %%
df['Literacy'].value_counts()
# Out:
# UNKNOWN           456197
# NO                193426
# READ & WRITE      119038
# Undefined Code         2
# N                      1
# Name: Literacy, dtype: int64

# %%
# write all passenger data to csv
df.to_csv('./italians_to_america.csv')

# %%
# create dataframe of manifest header data csv
manifests = pd.read_csv('./manifest_list_1855_1900.csv')
manifests.head()
# Out:
#    ManifestID   ShipName                    Port     Arrival
# 0           1   MASSILIA     MARSEILLES & NAPLES  04/04/1894
# 1           4     ITALIA                  NAPLES  04/07/1894
# 2           6   TEUTONIC  LIVERPOOL & QUEENSTOWN  04/15/1897
# 3           8  BRITANNIA     MARSEILLES & NAPLES  02/24/1890
# 4          11   CASTALIA                   HAVRE  11/08/1880

# %%
# convert Manifest ID in sicilydf to int to match manifest header file
sicilydf['ManifestID'] = sicilydf['ManifestID'].astype('int')

# %%
# add manifest header information to passenger dataframe
sicilydf = pd.merge(sicilydf, manifests, how='left', on='ManifestID')

# %%
sicilydf.head()
# Out:
#      LastName  FirstName                   Age        Occupation  \
# 0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3      CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 4      CARUSO       ROSA                    38              WIFE
#
#        Literacy CountyofOrigin CityTownofLastResidence DestinationCityTown  \
# 0  READ & WRITE          ITALY                 SCIACCA            NEW YORK
# 1  READ & WRITE          ITALY                 SCIACCA            NEW YORK
# 2            NO          ITALY                 SCIACCA            NEW YORK
# 3            NO          ITALY                 SCIACCA            NEW YORK
# 4  READ & WRITE          ITALY                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID   Province  \
# 0  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 1  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 2  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 3  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 4  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
#
#   ShipName    Port     Arrival
# 0      EMS  NAPLES  12/29/1892
# 1      EMS  NAPLES  12/29/1892
# 2      EMS  NAPLES  12/29/1892
# 3      EMS  NAPLES  12/29/1892
# 4      EMS  NAPLES  12/29/1892

# %%
sicilydf['Age'].value_counts()
# Out:
# 24    1327
# 23    1300
# 22    1245
# 25    1197
# 26    1175
#       ...
# 71      20
# 70      18
# 80      11
# 72      11
# 78       2
# Name: Age, Length: 86, dtype: int64

# %%
# fix typo in Country of Origin column
sicilydf.rename(columns={'CountyofOrigin':'CountryofOrigin'}, inplace=True)

# %%
# export passengers data for geocoding
sicilydf.to_csv('./sicily_passengers_raw.csv')

# %%
# bring in destinations lat/lng from geocoding notebook
csv = open('./geocode_results.csv')
dest_df = pd.read_csv(csv)
dest_df.head()
# Out:
#    Unnamed: 0         DestRaw              Dest  \
# 0           0        NEW YORK          NEW YORK
# 1           1  NEW-ORLEANS-LA   NEW ORLEANS, LA
# 2           2     NEW-ORLEANS   NEW ORLEANS, LA
# 3           3             USA               USA
# 4           4    PHILADELPHIA  PHILADELPHIA, PA
#
#                                   geocoder_results  \
# 0      <[OK] Google - Geocode [New York, NY, USA]>
# 1   <[OK] Google - Geocode [New Orleans, LA, USA]>
# 2   <[OK] Google - Geocode [New Orleans, LA, USA]>
# 3          <[OK] Google - Geocode [United States]>
# 4  <[OK] Google - Geocode [Philadelphia, PA, USA]>
#
#                                                 bbox  \
# 0  {'northeast': [40.9175771, -73.70027209999999]...
# 1  {'northeast': [30.199332, -89.625053], 'southw...
# 2  {'northeast': [30.199332, -89.625053], 'southw...
# 3  {'northeast': [49.38, -66.94], 'southwest': [2...
# 4  {'northeast': [40.1379919, -74.9557629], 'sout...
#
#                             latlong
# 0         [40.7127753, -74.0059728]
# 1  [29.95106579999999, -90.0715323]
# 2  [29.95106579999999, -90.0715323]
# 3            [37.09024, -95.712891]
# 4         [39.9525839, -75.1652215]

# %%
# rename DestRaw to match passenger df
dest_df.rename(columns={'DestRaw':'DestinationCityTown'}, inplace=True)

# %%
# add destination lat/lng information to passenger dataframe
sicilydf = pd.merge(sicilydf, dest_df, how='left', on='DestinationCityTown')
sicilydf.head()
# Out:
#      LastName  FirstName                   Age        Occupation  \
# 0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3      CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 4      CARUSO       ROSA                    38              WIFE
#
#        Literacy CountryofOrigin CityTownofLastResidence DestinationCityTown  \
# 0  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 1  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 2            NO           ITALY                 SCIACCA            NEW YORK
# 3            NO           ITALY                 SCIACCA            NEW YORK
# 4  READ & WRITE           ITALY                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID   Province  \
# 0  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 1  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 2  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 3  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 4  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
#
#   ShipName    Port     Arrival  Unnamed: 0      Dest  \
# 0      EMS  NAPLES  12/29/1892         0.0  NEW YORK
# 1      EMS  NAPLES  12/29/1892         0.0  NEW YORK
# 2      EMS  NAPLES  12/29/1892         0.0  NEW YORK
# 3      EMS  NAPLES  12/29/1892         0.0  NEW YORK
# 4      EMS  NAPLES  12/29/1892         0.0  NEW YORK
#
#                               geocoder_results  \
# 0  <[OK] Google - Geocode [New York, NY, USA]>
# 1  <[OK] Google - Geocode [New York, NY, USA]>
# 2  <[OK] Google - Geocode [New York, NY, USA]>
# 3  <[OK] Google - Geocode [New York, NY, USA]>
# 4  <[OK] Google - Geocode [New York, NY, USA]>
#
#                                                 bbox  \
# 0  {'northeast': [40.9175771, -73.70027209999999]...
# 1  {'northeast': [40.9175771, -73.70027209999999]...
# 2  {'northeast': [40.9175771, -73.70027209999999]...
# 3  {'northeast': [40.9175771, -73.70027209999999]...
# 4  {'northeast': [40.9175771, -73.70027209999999]...
#
#                      latlong
# 0  [40.7127753, -74.0059728]
# 1  [40.7127753, -74.0059728]
# 2  [40.7127753, -74.0059728]
# 3  [40.7127753, -74.0059728]
# 4  [40.7127753, -74.0059728]

# %%
sicilydf = sicilydf.drop(['Unnamed: 0','Dest','geocoder_results'], axis='columns')

# %%
# remove rows with no location data
sicilydf.dropna(subset=['latlong'], inplace=True)

# %%
sicilydf.head()
# Out:
#      LastName  FirstName                   Age        Occupation  \
# 0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3      CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 4      CARUSO       ROSA                    38              WIFE
#
#        Literacy CountryofOrigin CityTownofLastResidence DestinationCityTown  \
# 0  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 1  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 2            NO           ITALY                 SCIACCA            NEW YORK
# 3            NO           ITALY                 SCIACCA            NEW YORK
# 4  READ & WRITE           ITALY                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID   Province  \
# 0  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 1  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 2  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 3  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 4  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
#
#   ShipName    Port     Arrival  \
# 0      EMS  NAPLES  12/29/1892
# 1      EMS  NAPLES  12/29/1892
# 2      EMS  NAPLES  12/29/1892
# 3      EMS  NAPLES  12/29/1892
# 4      EMS  NAPLES  12/29/1892
#
#                                                 bbox  \
# 0  {'northeast': [40.9175771, -73.70027209999999]...
# 1  {'northeast': [40.9175771, -73.70027209999999]...
# 2  {'northeast': [40.9175771, -73.70027209999999]...
# 3  {'northeast': [40.9175771, -73.70027209999999]...
# 4  {'northeast': [40.9175771, -73.70027209999999]...
#
#                      latlong
# 0  [40.7127753, -74.0059728]
# 1  [40.7127753, -74.0059728]
# 2  [40.7127753, -74.0059728]
# 3  [40.7127753, -74.0059728]
# 4  [40.7127753, -74.0059728]

# %%
# separate coords into two columns
sicilydf['lat'] = sicilydf['latlong'].apply(lambda x: x.split(",")[0].replace("[",""))
sicilydf['lng'] = sicilydf['latlong'].apply(lambda x: x.split(",")[1].replace("]",""))
sicilydf.head()
# Out:
#      LastName  FirstName                   Age        Occupation  \
# 0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3      CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 4      CARUSO       ROSA                    38              WIFE
#
#        Literacy CountryofOrigin CityTownofLastResidence DestinationCityTown  \
# 0  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 1  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 2            NO           ITALY                 SCIACCA            NEW YORK
# 3            NO           ITALY                 SCIACCA            NEW YORK
# 4  READ & WRITE           ITALY                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID   Province  \
# 0  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 1  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 2  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 3  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 4  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
#
#   ShipName    Port     Arrival  \
# 0      EMS  NAPLES  12/29/1892
# 1      EMS  NAPLES  12/29/1892
# 2      EMS  NAPLES  12/29/1892
# 3      EMS  NAPLES  12/29/1892
# 4      EMS  NAPLES  12/29/1892
#
#                                                 bbox  \
# 0  {'northeast': [40.9175771, -73.70027209999999]...
# 1  {'northeast': [40.9175771, -73.70027209999999]...
# 2  {'northeast': [40.9175771, -73.70027209999999]...
# 3  {'northeast': [40.9175771, -73.70027209999999]...
# 4  {'northeast': [40.9175771, -73.70027209999999]...
#
#                      latlong         lat           lng
# 0  [40.7127753, -74.0059728]  40.7127753   -74.0059728
# 1  [40.7127753, -74.0059728]  40.7127753   -74.0059728
# 2  [40.7127753, -74.0059728]  40.7127753   -74.0059728
# 3  [40.7127753, -74.0059728]  40.7127753   -74.0059728
# 4  [40.7127753, -74.0059728]  40.7127753   -74.0059728

# %%
# separate arrival year
sicilydf['ArrivalYr'] = pd.to_datetime(sicilydf['Arrival']).dt.year

# %%
sicilydf.to_csv('../data/sicily_passengers.csv')

# %%
sicilydf.groupby('ArrivalYr').size()
# Out:
# ArrivalYr
# 1880       28
# 1881       98
# 1882      443
# 1883      188
# 1884      127
# 1885      157
# 1886      136
# 1887      341
# 1888      527
# 1889      316
# 1890     1252
# 1891      767
# 1892     1345
# 1893     2762
# 1894     1055
# 1895      395
# 1896     1077
# 1897     3400
# 1898     8014
# 1899     6479
# 1900    10697
# dtype: int64

# %%
origin_csv = open('./origin_geocode_results.csv', 'r', newline='')
df_origin = pd.read_csv(origin_csv)

# %%
sicily_csv = open('../data/sicily_passengers.csv', 'r', newline='')
sicilydf = pd.read_csv(sicily_csv)

# %%
df_origin.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  origin_city origin_country  \
# 0           0             0      SCIACCA          ITALY
# 1           1             1      PALERMO          ITALY
# 2           2             2      MESSINA          ITALY
# 3           3             3  POGGIOREALE          ITALY
# 4           4             4   SALAPARUTA          ITALY
#
#                                     geocoder_results  origin_lon  origin_lat
# 0  <[OK] Google - Geocode [92019 Sciacca, AG, Ita...   13.081630   37.508515
# 1  <[OK] Google - Geocode [Palermo, Province of P...   13.361487   38.115690
# 2  <[OK] Google - Geocode [Messina, Province of M...   15.554206   38.193734
# 3  <[OK] Google - Geocode [91020 Poggioreale, Pro...   13.034974   37.763177
# 4  <[OK] Google - Geocode [91020 Salaparuta, Prov...   13.010526   37.758554

# %%
sicilydf.head()
# Out:
#    Unnamed: 0    LastName  FirstName                   Age        Occupation  \
# 0           0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1           1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2           2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3           3      CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 4           4      CARUSO       ROSA                    38              WIFE
#
#        Literacy CountryofOrigin CityTownofLastResidence DestinationCityTown  \
# 0  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 1  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 2            NO           ITALY                 SCIACCA            NEW YORK
# 3            NO           ITALY                 SCIACCA            NEW YORK
# 4  READ & WRITE           ITALY                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID   Province  \
# 0  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 1  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 2  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 3  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
# 4  Return trip to USA - non US Citizen [Transit];...       82236  Agrigento
#
#   ShipName    Port     Arrival  \
# 0      EMS  NAPLES  12/29/1892
# 1      EMS  NAPLES  12/29/1892
# 2      EMS  NAPLES  12/29/1892
# 3      EMS  NAPLES  12/29/1892
# 4      EMS  NAPLES  12/29/1892
#
#                                                 bbox  \
# 0  {'northeast': [40.9175771, -73.70027209999999]...
# 1  {'northeast': [40.9175771, -73.70027209999999]...
# 2  {'northeast': [40.9175771, -73.70027209999999]...
# 3  {'northeast': [40.9175771, -73.70027209999999]...
# 4  {'northeast': [40.9175771, -73.70027209999999]...
#
#                      latlong        lat        lng  ArrivalYr
# 0  [40.7127753, -74.0059728]  40.712775 -74.005973       1892
# 1  [40.7127753, -74.0059728]  40.712775 -74.005973       1892
# 2  [40.7127753, -74.0059728]  40.712775 -74.005973       1892
# 3  [40.7127753, -74.0059728]  40.712775 -74.005973       1892
# 4  [40.7127753, -74.0059728]  40.712775 -74.005973       1892

# %%
# add origin lat/lng information to passenger dataframe
sicilydf = pd.merge(sicilydf, df_origin, how='left', left_on='CityTownofLastResidence', right_on='origin_city')
sicilydf.head()
# Out:
#    Unnamed: 0_x    LastName  FirstName                   Age  \
# 0             0  BUONGIORNO    ANTONIO                    49
# 1             1  BUONGIORNO   GIUSEPPE                    60
# 2             2      CARUSO  FRANCESCA  Infant in months: 10
# 3             3      CARUSO  FRANCESCO                    03
# 4             4      CARUSO       ROSA                    38
#
#          Occupation      Literacy CountryofOrigin CityTownofLastResidence  \
# 0        BLACKSMITH  READ & WRITE           ITALY                 SCIACCA
# 1        BLACKSMITH  READ & WRITE           ITALY                 SCIACCA
# 2            INFANT            NO           ITALY                 SCIACCA
# 3  CHILD, YOUNGSTER            NO           ITALY                 SCIACCA
# 4              WIFE  READ & WRITE           ITALY                 SCIACCA
#
#   DestinationCityTown                           TransitTravelCompartment  ...  \
# 0            NEW YORK  Return trip to USA - non US Citizen [Transit];...  ...
# 1            NEW YORK  Return trip to USA - non US Citizen [Transit];...  ...
# 2            NEW YORK  Return trip to USA - non US Citizen [Transit];...  ...
# 3            NEW YORK  Return trip to USA - non US Citizen [Transit];...  ...
# 4            NEW YORK  Return trip to USA - non US Citizen [Transit];...  ...
#
#          lat        lng ArrivalYr Unnamed: 0_y Unnamed: 0.1 origin_city  \
# 0  40.712775 -74.005973      1892            0            0     SCIACCA
# 1  40.712775 -74.005973      1892            0            0     SCIACCA
# 2  40.712775 -74.005973      1892            0            0     SCIACCA
# 3  40.712775 -74.005973      1892            0            0     SCIACCA
# 4  40.712775 -74.005973      1892            0            0     SCIACCA
#
#   origin_country                                   geocoder_results  \
# 0          ITALY  <[OK] Google - Geocode [92019 Sciacca, AG, Ita...
# 1          ITALY  <[OK] Google - Geocode [92019 Sciacca, AG, Ita...
# 2          ITALY  <[OK] Google - Geocode [92019 Sciacca, AG, Ita...
# 3          ITALY  <[OK] Google - Geocode [92019 Sciacca, AG, Ita...
# 4          ITALY  <[OK] Google - Geocode [92019 Sciacca, AG, Ita...
#
#    origin_lon  origin_lat
# 0    13.08163   37.508515
# 1    13.08163   37.508515
# 2    13.08163   37.508515
# 3    13.08163   37.508515
# 4    13.08163   37.508515
#
# [5 rows x 27 columns]

# %%
sicilydf = sicilydf.drop(['Unnamed: 0_x','latlong','geocoder_results','Unnamed: 0_y','Unnamed: 0.1','origin_country'], axis='columns')

# %%
sicilydf.head()
# Out:
#      LastName  FirstName                   Age        Occupation  \
# 0  BUONGIORNO    ANTONIO                    49        BLACKSMITH
# 1  BUONGIORNO   GIUSEPPE                    60        BLACKSMITH
# 2      CARUSO  FRANCESCA  Infant in months: 10            INFANT
# 3      CARUSO  FRANCESCO                    03  CHILD, YOUNGSTER
# 4      CARUSO       ROSA                    38              WIFE
#
#        Literacy CountryofOrigin CityTownofLastResidence DestinationCityTown  \
# 0  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 1  READ & WRITE           ITALY                 SCIACCA            NEW YORK
# 2            NO           ITALY                 SCIACCA            NEW YORK
# 3            NO           ITALY                 SCIACCA            NEW YORK
# 4  READ & WRITE           ITALY                 SCIACCA            NEW YORK
#
#                             TransitTravelCompartment  ManifestID  ...  \
# 0  Return trip to USA - non US Citizen [Transit];...       82236  ...
# 1  Return trip to USA - non US Citizen [Transit];...       82236  ...
# 2  Return trip to USA - non US Citizen [Transit];...       82236  ...
# 3  Return trip to USA - non US Citizen [Transit];...       82236  ...
# 4  Return trip to USA - non US Citizen [Transit];...       82236  ...
#
#   ShipName    Port     Arrival  \
# 0      EMS  NAPLES  12/29/1892
# 1      EMS  NAPLES  12/29/1892
# 2      EMS  NAPLES  12/29/1892
# 3      EMS  NAPLES  12/29/1892
# 4      EMS  NAPLES  12/29/1892
#
#                                                 bbox        lat        lng  \
# 0  {'northeast': [40.9175771, -73.70027209999999]...  40.712775 -74.005973
# 1  {'northeast': [40.9175771, -73.70027209999999]...  40.712775 -74.005973
# 2  {'northeast': [40.9175771, -73.70027209999999]...  40.712775 -74.005973
# 3  {'northeast': [40.9175771, -73.70027209999999]...  40.712775 -74.005973
# 4  {'northeast': [40.9175771, -73.70027209999999]...  40.712775 -74.005973
#
#    ArrivalYr  origin_city origin_lon  origin_lat
# 0       1892      SCIACCA   13.08163   37.508515
# 1       1892      SCIACCA   13.08163   37.508515
# 2       1892      SCIACCA   13.08163   37.508515
# 3       1892      SCIACCA   13.08163   37.508515
# 4       1892      SCIACCA   13.08163   37.508515
#
# [5 rows x 21 columns]

# %%
sicilydf.to_csv('../data/sicily_passengers2.csv')
