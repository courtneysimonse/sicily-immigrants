# %% [markdown]
# ## Formatting Passenger Data

# %%
import pandas as pd
import numpy as np

# %%
# open data file
csv = open('../data/sicily_passengers2.csv')
df = pd.read_csv(csv)

# %%
df.head()
# Out:
#    Unnamed: 0    LastName  FirstName                   Age        Occupation  \
# 0           0  Buongiorno    Antonio                    49        Blacksmith
# 1           1  Buongiorno   Giuseppe                    60        Blacksmith
# 2           2      Caruso  Francesca  Infant in months: 10            Infant
# 3           3      Caruso  Francesco                    03  Child, Youngster
# 4           4      Caruso       Rosa                    38              Wife
#
#        Literacy CountryofOrigin CityTownofLastResidence destination_city  \
# 0  Read & Write           ITALY                 SCIACCA         New York
# 1  Read & Write           ITALY                 SCIACCA         New York
# 2            No           ITALY                 SCIACCA         New York
# 3            No           ITALY                 SCIACCA         New York
# 4  Read & Write           ITALY                 SCIACCA         New York
#
# ...

# %%
df['LastName'] = df['LastName'].str.title()

# %%
df['FirstName'] = df['FirstName'].str.title()
df['Occupation'] = df['Occupation'].str.title()
df['Literacy'] = df['Literacy'].str.title()
df['origin_city'] = df['origin_city'].str.title()
df['DestinationCityTown'] = df['DestinationCityTown'].str.title()

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=39604, step=1),
#  Index(['Unnamed: 0', 'LastName', 'FirstName', 'Age', 'Occupation', 'Literacy',
#         'CountryofOrigin', 'CityTownofLastResidence', 'DestinationCityTown',
#         'TransitTravelCompartment', 'ManifestID', 'Province', 'ShipName',
#         'Port', 'Arrival', 'bbox', 'lat', 'lng', 'ArrivalYr', 'origin_city',
#         'origin_lon', 'origin_lat'],
#        dtype='object')]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#      LastName  FirstName                   Age        Occupation  \
# 0  Buongiorno    Antonio                    49        Blacksmith
# 1  Buongiorno   Giuseppe                    60        Blacksmith
# 2      Caruso  Francesca  Infant in months: 10            Infant
# 3      Caruso  Francesco                    03  Child, Youngster
# 4      Caruso       Rosa                    38              Wife
#
#        Literacy CountryofOrigin CityTownofLastResidence destination_city  \
# 0  Read & Write           ITALY                 SCIACCA         New York
# 1  Read & Write           ITALY                 SCIACCA         New York
# 2            No           ITALY                 SCIACCA         New York
# 3            No           ITALY                 SCIACCA         New York
# 4  Read & Write           ITALY                 SCIACCA         New York
#
#                             TransitTravelCompartment  ManifestID  ...  \
# ...

# %%
df.to_csv('../data/sicily_passengers2.csv',"'")
